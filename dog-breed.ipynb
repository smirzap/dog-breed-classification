# %% [markdown]
# # End-to-end Multi-Class Dob Breed Classification
#
# Notebook ini membangun classifier yang dapat mengklasifikan jenis anjing berdasarkan foto. Teknologi yang digunakan adalah TensorFlow dan TensorFlow Hub.
#
# ## 1. Problem
#
# Mengidentifikasi jenis anjing berdasarkan foto yang diberikan.
#
# ## 2. Data
#
# Data train dan test set berasal dari [Kaggle's Dog Breed Identification competetition](https://www.kaggle.com/c/dog-breed-identification)
#
# ## 3. Evaluation
#
# Hasil evaluasi adalah probability dari image yang diberikan diklasifikasikan pada setiap jenis anjing
#
# [Detail disini](https://www.kaggle.com/c/dog-breed-identification/overview/evaluation)
#
# ## 4. Features
#
# Berikut informasi terkait data:
# * Images sebagai unstructured data. Oleh karena itu kita gunakan Deep Learning dan Transfer Learning
# * Terdapat 120 jenis anjing sehingga ada 120 classes
# * Terdapat 10.000+ gambar dalam training set
# * Terdapat 10.000+ gambar pada test set

# %% [markdown]
# ### Get our workspace ready
#
# * import tensorflow
# * import tensorflow hub
# * Make sure we are using GPU

# %%
# Import TensorFlow and check the version
import tensorflow as tf
import tensorflow_hub as hub
print(tf.__version__)
print(hub.__version__)
# Out:
# 2.8.0
# 0.12.0

# %%
# Check GPU availability

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/Colab Notebooks/projects/dog-breed'

# %%
# %cd '/content/drive/MyDrive/Colab Notebooks/projects/dog-breed'
# Out:
# /content/drive/MyDrive/Colab Notebooks/projects/dog-breed

# %%
# %ls
# Out:
# dog-breed.ipynb
